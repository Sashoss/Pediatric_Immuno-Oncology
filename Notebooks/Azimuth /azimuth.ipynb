# %% [markdown]
# ### Azimuth

# %%
library(Seurat)
library(Azimuth)
library(SeuratData)
library(patchwork)
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
# 'SeuratObject' was built with package 'Matrix' 1.7.0 but the current
# version is 1.7.1; it is recomended that you reinstall 'SeuratObject' as
# the ABI for 'Matrix' may have changed
#
#
# Attaching package: 'SeuratObject'
#
#
# The following objects are masked from 'package:base':
#
#     intersect, t
#
#
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat
#
#
#
# Attaching shinyBS
#
# -- Installed datasets -------------------------------- SeuratData v0.2.2.9001 --
#
# v pbmcref 1.0.0                         v pbmcsca 3.0.0
#
#
# -------------------------------------- Key -------------------------------------
#
# v Dataset loaded successfully
# > Dataset built with a newer version of Seurat than installed
# (?) Unknown version of Seurat installed
#
#
# Warning message:
# "package 'patchwork' was built under R version 4.4.1"

# %%
getwd()
# Out:
# [1] "/Users/shiwani/Documents/GITHUB/Pediatric_Immuno-Oncology/Notebooks/Azimuth "

# %%
seurat_obj <- readRDS("../Clustering/out/clustered_harmony.rds")

# %%
head(seurat_obj@meta.data)
# Out:
#                                      orig.ident        nCount_RNA nFeature_RNA
# GSM8375832_GBM1_L_AAACCTGAGACAGACC-1 GSM8375832_GBM1_L  9492      3346
# GSM8375832_GBM1_L_AAACCTGAGACTTTCG-1 GSM8375832_GBM1_L  1751      1189
# GSM8375832_GBM1_L_AAACCTGAGGCTATCT-1 GSM8375832_GBM1_L  2684      1698
# GSM8375832_GBM1_L_AAACCTGAGTGAAGAG-1 GSM8375832_GBM1_L  5594      2974
# GSM8375832_GBM1_L_AAACCTGAGTGCGTGA-1 GSM8375832_GBM1_L  4956      2478
# GSM8375832_GBM1_L_AAACCTGAGTGTACTC-1 GSM8375832_GBM1_L 14145      4849
#                                      sample_name       diagnosis    age sex
# GSM8375832_GBM1_L_AAACCTGAGACAGACC-1 GSM8375832_GBM1_L Glioblastoma NA  NA
# GSM8375832_GBM1_L_AAACCTGAGACTTTCG-1 GSM8375832_GBM1_L Glioblastoma NA  NA
# GSM8375832_GBM1_L_AAACCTGAGGCTATCT-1 GSM8375832_GBM1_L Glioblastoma NA  NA
# GSM8375832_GBM1_L_AAACCTGAGTGAAGAG-1 GSM8375832_GBM1_L Glioblastoma NA  NA
# GSM8375832_GBM1_L_AAACCTGAGTGCGTGA-1 GSM8375832_GBM1_L Glioblastoma NA  NA
# ...

# %%
# The RunAzimuth function can take a Seurat object as input
pbmcsca <- RunAzimuth(seurat_obj, reference = "pbmcref")
# Out:
# Warning message:
# "Overwriting miscellanous data for model"
# Warning message:
# "Adding a dimensional reduction (refUMAP) without the associated assay being present"
# Warning message:
# "Adding a dimensional reduction (refUMAP) without the associated assay being present"
# detected inputs from HUMAN with id type Gene.name
#
# reference rownames detected HUMAN with id type Gene.name
#
# Normalizing query using reference SCT model
#
# Warning message:
# "597 features of the features specified were not present in both the reference query assays.
# Continuing with remaining 4403 features."
# Projecting cell embeddings
#
# Finding query neighbors
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 4160 anchors
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Predicting cell labels
#
# Predicting cell labels
#
# Warning message:
# "Feature names cannot have underscores ('_'), replacing with dashes ('-')"
# Predicting cell labels
#
# Warning message:
# ...

# %%
p1 <- DimPlot(seurat_obj, group.by = "sample_name", label = TRUE, label.size = 3) + NoLegend()
p2 <- DimPlot(seurat_obj, group.by = "seurat_clusters")
p1 + p2
# Out:
# plot without title

# %%
seurat_subset <- subset[seurat_obj, subset = seurat_obj@meta.data$seurat_clusters==8]
# Out:
# Error in parse(text = input): <text>:1:82: unexpected '='
# 1: seurat_subset <- subset[seurat_obj, subset = seurat_obj@meta.data$seurat_clusters=
#                                                                                      ^
# Traceback:

# %%
bm <- RunAzimuth(query = seurat_obj, reference = "pbmcref")
# Out:
# Warning message:
# "Overwriting miscellanous data for model"
# Warning message:
# "Adding a dimensional reduction (refUMAP) without the associated assay being present"
# Warning message:
# "Adding a dimensional reduction (refUMAP) without the associated assay being present"
# detected inputs from HUMAN with id type Gene.name
#
# reference rownames detected HUMAN with id type Gene.name
#
# Normalizing query using reference SCT model
#
# Warning message:
# "597 features of the features specified were not present in both the reference query assays.
# Continuing with remaining 4403 features."
# Projecting cell embeddings
# Error in h(simpleError(msg, call)): error in evaluating the argument 'x' in selecting a method for function 't': vector memory limit of 16.0 Gb reached, see mem.maxVSize()
# Traceback:
#
# 1. RunAzimuth.Seurat(query = seurat_obj, reference = "pbmcref")
# 2. FindTransferAnchors(reference = reference, query = query, k.filter = NA,
# ...
